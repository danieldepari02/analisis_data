# %% [markdown]
# # Proyek Analisis Data: Bike Sharing Dataset
# - **Nama:** Daniel Valerian Depari
# - **Email:** danieldepari02@gmail.com
# - **ID Dicoding:** daniel_valerian

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Pertanyaan 1: Bagaimana hari mempengaruhi jumlah peminjaman sepeda?
# - Pertanyaan 2: Bagaimana musim mempengaruhi jumlah peminjaman sepeda pada periode tahun 2011 dan 2012?
# - Pertanyaan 3: Bagaimana waktu (jam) mempengaruhi jumlah peminjaman sepeda?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
day_df = pd.read_csv("https://raw.githubusercontent.com/danieldepari02/proyek_analisis_data/main/day.csv")
day_df
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
hour_df = pd.read_csv("https://raw.githubusercontent.com/danieldepari02/proyek_analisis_data/main/hour.csv")
hour_df
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01       1   0     1   0        0        6
# 1            2  2011-01-01       1   0     1   1        0        6
# 2            3  2011-01-01       1   0     1   2        0        6
# 3            4  2011-01-01       1   0     1   3        0        6
# 4            5  2011-01-01       1   0     1   4        0        6
# ...        ...         ...     ...  ..   ...  ..      ...      ...
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 0               0           1  0.24  0.2879  0.81     0.0000       3
# ...

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# ##### Menilai tabel day_df

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
day_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
print("Jumlah duplikasi: ", day_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
day_df.describe(include="all")
# Out:
#            instant      dteday      season          yr        mnth  \
# count   731.000000         731  731.000000  731.000000  731.000000
# unique         NaN         731         NaN         NaN         NaN
# top            NaN  2011-01-01         NaN         NaN         NaN
# freq           NaN           1         NaN         NaN         NaN
# mean    366.000000         NaN    2.496580    0.500684    6.519836
# std     211.165812         NaN    1.110807    0.500342    3.451913
# min       1.000000         NaN    1.000000    0.000000    1.000000
# 25%     183.500000         NaN    2.000000    0.000000    4.000000
# 50%     366.000000         NaN    3.000000    1.000000    7.000000
# 75%     548.500000         NaN    3.000000    1.000000   10.000000
# max     731.000000         NaN    4.000000    1.000000   12.000000
#
#            holiday     weekday  workingday  weathersit        temp  \
# count   731.000000  731.000000  731.000000  731.000000  731.000000
# ...

# %% [markdown]
# ##### Menilai tabel hour_df

# %%
print("Jumlah duplikasi: ",hour_df.duplicated().sum())
hour_df.describe(include="all")
# Out:
# Jumlah duplikasi:  0
#            instant      dteday        season            yr          mnth  \
# count   17379.0000       17379  17379.000000  17379.000000  17379.000000
# unique         NaN         731           NaN           NaN           NaN
# top            NaN  2011-01-01           NaN           NaN           NaN
# freq           NaN          24           NaN           NaN           NaN
# mean     8690.0000         NaN      2.501640      0.502561      6.537775
# std      5017.0295         NaN      1.106918      0.500008      3.438776
# min         1.0000         NaN      1.000000      0.000000      1.000000
# 25%      4345.5000         NaN      2.000000      0.000000      4.000000
# 50%      8690.0000         NaN      3.000000      1.000000      7.000000
# 75%     13034.5000         NaN      3.000000      1.000000     10.000000
# max     17379.0000         NaN      4.000000      1.000000     12.000000
#
# ...

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
hour_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Membersihkan tabel day_df
# ##### Memperbaiki tipe data

# %%
dteday_columns = ["dteday"]
 
for column in dteday_columns:
  day_df[column] = pd.to_datetime(day_df[column])

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    datetime64[ns]
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(11)
# memory usage: 91.5 KB

# %% [markdown]
# #### Membersihkan tabel hour_df
# ##### Memperbaiki tipe data

# %%
dteday_columns = ["dteday"]
 
for column in dteday_columns:
  hour_df[column] = pd.to_datetime(hour_df[column])

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  datetime64[ns]
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(12)
# memory usage: 2.3 MB

# %% [markdown]
# ### Exploratory Data Analysis (EDA)
# ##### Explore day_df

# %% [markdown]
# #### Bike Renting Rate towards Day of Week

# %%
df_time = day_df.copy()
df = df_time.copy()


df['weekday'] = df['weekday'].map({0: 'Sunday', 1: 'Monday', 2: 'Tuesday', 3: 'Wednesday', 4: 'Thursday', 5: 'Friday', 6: 'Saturday'})



pivot_weekday = df.groupby(by=["weekday"]).agg({
    "cnt": "mean"
}).reindex(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']).reset_index()

pd.options.display.float_format = '{:.2f}'.format
print("\n===============================================\n")
print("Average Bike Renting number for each day")
print(pivot_weekday.to_string(index=False))
print("\n===============================================\n")
# Out:
# ...
#
# Average Bike Renting number for each day
#   weekday     cnt
#    Monday 4338.12
#   Tuesday 4510.66
# Wednesday 4548.54
#  Thursday 4667.26
#    Friday 4690.29
#  Saturday 4550.54
#    Sunday 4228.83
#
# ...

# %% [markdown]
# #### Bike Renting towards Weather and Season

# %%
df = df_time.copy()


df['weathersit'] = df['weathersit'].map({1: 'Clear', 2: 'Cloudy', 3: 'Light Rain', 4: 'Heavy Rain'})
df['season'] = df['season'].map({1: 'Spring', 2: 'Summer', 3: 'Fall', 4: 'Winter'})


weathersit_order = ['Clear', 'Cloudy', 'Light Rain', 'Heavy Rain']
season_order = ['Spring', 'Summer', 'Fall', 'Winter']


pivot_weathersit = df.groupby(by=["weathersit"]).agg({
    "cnt": "mean"
}).reindex(weathersit_order, fill_value=0).reset_index()
pivot_season = df.groupby(by=["season"]).agg({
    "cnt": "mean"
}).reindex(season_order, fill_value=0).reset_index()


pd.options.display.float_format = '{:.2f}'.format
print("Average Bike Renting towards weather:")
print(pivot_weathersit.to_string(index=False))
print("\n===============================================\n")
print("Average Bike Renting towards season :")
print(pivot_season.to_string(index=False))
# Out:
# Average Bike Renting towards weather:
# weathersit     cnt
#      Clear 4876.79
#     Cloudy 4035.86
# Light Rain 1803.29
# Heavy Rain    0.00
#
# ...
#
# Average Bike Renting towards season :
# season     cnt
# Spring 2604.13
# Summer 4992.33
#   Fall 5644.30
# Winter 4728.16

# %% [markdown]
# #### Bike Renting Rates towards Hours of Day

# %%
df_time = hour_df.copy()
df = df_time.copy()


df['hr'] = df['hr'].map({0: '00.00', 1: '01.00', 2: '02.00', 3: '03.00', 4: '04.00', 5: '05.00', 6: '06.00', 7: '07.00', 8: '08.00', 9: '09.00', 10: '10.00', 11: '11.00', 12: '12.00', 13: '13.00', 14: '14.00', 15: '15.00', 16: '16.00', 17: '17.00', 18: '18.00', 19: '19.00', 20: '20.00', 21: '21.00', 22: '22.00', 23: '23.00'})
hr_order = ['00.00', '01.00', '02.00', '03.00', '04.00', '05.00', '06.00', '07.00', '08.00', '09.00', '10.00', '11.00', '12.00', '13.00', '14.00', '15.00', '16.00', '17.00', '18.00', '19.00', '20.00', '21.00', '22.00', '23.00']

pivot_hr = df.groupby(by=["hr"]).agg({
    "cnt": "mean"
}).reindex(hr_order, fill_value=0).reset_index()

#df['weathersit'] = df['weathersit'].map({1: 'Clear', 2: 'Cloudy', 3: 'Light Rain', 4: 'Heavy Rain'})
#weathersit_order = ['Clear', 'Cloudy', 'Light Rain', 'Heavy Rain']



#pivot_weathersit = df.groupby(by=["weathersit"]).agg({
  #  "cnt": "mean"
#}).reindex(weathersit_order, fill_value=0).reset_index()

pd.options.display.float_format = '{:.2f}'.format
print("\n===============================================\n")
print("Average Bike Renting number for each hour")
print(pivot_hr.to_string(index=False))
print("\n===============================================\n")
# Out:
# ...
#
# Average Bike Renting number for each hour
#    hr    cnt
# 00.00  53.90
# 01.00  33.38
# 02.00  22.87
# 03.00  11.73
# 04.00   6.35
# 05.00  19.89
# 06.00  76.04
# 07.00 212.06
# 08.00 359.01
# 09.00 219.31
# 10.00 173.67
# 11.00 208.14
# 12.00 253.32
# 13.00 253.66
# 14.00 240.95
# 15.00 251.23
# 16.00 311.98
# 17.00 461.45
# 18.00 425.51
# 19.00 311.52
# 20.00 226.03
# 21.00 172.31
# 22.00 131.34
# 23.00  87.83
#
# ...

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ##### Grafik Histogram dari day_df

# %%
day_df.hist()
# Out:
# array([[<Axes: title={'center': 'instant'}>,
#         <Axes: title={'center': 'dteday'}>,
#         <Axes: title={'center': 'season'}>,
#         <Axes: title={'center': 'yr'}>],
#        [<Axes: title={'center': 'mnth'}>,
#         <Axes: title={'center': 'holiday'}>,
#         <Axes: title={'center': 'weekday'}>,
#         <Axes: title={'center': 'workingday'}>],
#        [<Axes: title={'center': 'weathersit'}>,
#         <Axes: title={'center': 'temp'}>,
#         <Axes: title={'center': 'atemp'}>,
#         <Axes: title={'center': 'hum'}>],
#        [<Axes: title={'center': 'windspeed'}>,
#         <Axes: title={'center': 'casual'}>,
#         <Axes: title={'center': 'registered'}>,
#         <Axes: title={'center': 'cnt'}>]], dtype=object)

# %% [markdown]
# ##### Grafik Histogram dari hour_df

# %%
hour_df.hist()
# Out:
# array([[<Axes: title={'center': 'instant'}>,
#         <Axes: title={'center': 'dteday'}>,
#         <Axes: title={'center': 'season'}>,
#         <Axes: title={'center': 'yr'}>],
#        [<Axes: title={'center': 'mnth'}>, <Axes: title={'center': 'hr'}>,
#         <Axes: title={'center': 'holiday'}>,
#         <Axes: title={'center': 'weekday'}>],
#        [<Axes: title={'center': 'workingday'}>,
#         <Axes: title={'center': 'weathersit'}>,
#         <Axes: title={'center': 'temp'}>,
#         <Axes: title={'center': 'atemp'}>],
#        [<Axes: title={'center': 'hum'}>,
#         <Axes: title={'center': 'windspeed'}>,
#         <Axes: title={'center': 'casual'}>,
#         <Axes: title={'center': 'registered'}>],
#        [<Axes: title={'center': 'cnt'}>, <Axes: >, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
df = df_time.copy()

columns_to_plot = ['season', 'holiday', 'workingday', 'weathersit']


fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(14, 3))  
plt.subplots_adjust(hspace=0.5, wspace=0.5)

for i, column in enumerate(columns_to_plot):
    sns.histplot(df[column], ax=axes[i], kde=True)
    axes[i].set_title(f" {column}")
    axes[i].set_xlabel('') 

plt.tight_layout()
plt.show()

# %%
db = df_time.copy()

columns_to_plot = ['hr']


fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(14, 3))  
plt.subplots_adjust(hspace=0.5, wspace=0.5)

sns.histplot(df[column], kde=True)
 

plt.tight_layout()
plt.show()

# %% [markdown]
# ###### Pertanyaan 1: Bagaimana hari mempengaruhi jumlah peminjaman sepeda?

# %% [markdown]
# Berdasarkan data output, dapat terlihat bahwa peminjaman sepeda mencapai angka yang tinggi pada hari kerja dibandingkan weekend atau hari libur. Pada hari kerja, angka peminjaman tertinggi pada hari Jumat dan angka terendah pada hari minggu. Grafik dibawah ini menampilkan jumlah peminjaman rata-rata per hari. Dari grafik tersebut, tampak tren peningkatan dari hari senin hingga jumat dan kemudian terjadi tren negatif pada hari sabtu dan minggu yang merupakan hari libur.

# %%
plt.figure(figsize=(10, 6))
plt.plot(pivot_weekday['weekday'], pivot_weekday['cnt'], marker='o', color='green', linestyle='-')
plt.title('Average Bike Renting Number for Each Day')
plt.xlabel('Day')
plt.ylabel('Average Count')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Pertanyaan 2: Bagaimana musim mempengaruhi jumlah peminjaman sepeda pada periode tahun 2011 dan 2012?

# %% [markdown]
# Berdasarkan data output dari dataset, peminjaman sepeda tertinggi dilakukan ketika cuaca cerah. tren peminjaman sepeda mengalami penurunan ketika cuaca berkabut, hujan ringan, dan tidak ada peminjaman sepeda ketika cuaca hujan lebat. Berdasarkan musim, peminjaman sepeda tertinggi pada musim gugur dan diikuti dengan musim panas. Namun, peminjaman sepeda terendah terjadi pada musim semi. Grafik dibawah ini menampilkan tren peminjaman sepeda pada tahun 2011 dan 2012 terhadap musim setiap tahunnya. Dari tahun ke tahun, tampak terjadi pertambahan peminjaman sepeda pada tiap musim dari 2011 ke 2012. Namun, secara umum, pada musim gugur memiliki peminjam sepeda terbanyak dan musim semi memiliki jumlah peminjam sepeda terendah.

# %%
df = df_time.copy()

df['season'] = df['season'].map({1: 'Spring', 2: 'Summer', 3: 'Fall', 4: 'Winter'})
df['yr'] = df['yr'].map({0: '2011', 1: '2012'})


pivot_season_year = df.groupby(['season', 'yr'])['cnt'].sum().reset_index()
x = pivot_season_year['season'].unique()
y1 = pivot_season_year[pivot_season_year['yr'] == '2011']['cnt']
y2 = pivot_season_year[pivot_season_year['yr'] == '2012']['cnt']

plt.figure(figsize=(10, 6))
plt.bar(x, y1, color='skyblue', label='2011', width=0.4, alpha=0.8)
plt.bar(x, y2, bottom=y1, color='salmon', label='2012', width=0.4, alpha=0.8)

plt.xlabel('Season')
plt.ylabel('Bike Renting (Juta)')
plt.title('Bike Renting according Year and Season')
plt.legend(title='Year')

plt.tight_layout()
plt.show()

# %% [markdown]
# ###### Pertanyaan 3: Bagaimana waktu (jam) mempengaruhi jumlah peminjaman sepeda?

# %% [markdown]
# Grafik berikut menampilkan rata-rata peminjaman sepeda untuk setiap jam setiap harinya. Berdasarkan grafik tersebut, peminjaman sepeda tertinggi pada pukul 17.00 dan angka terendah terjadi pada pukul 04.00. Data tersebut disebabkan pukul 17.00 merupakan waktu pekerja kembali dari kantor/tempat bekerja sementara pukul 04.00 merupakan waktu sebagian besar pekerja masih berada di tempat tinggal masing-masing. Titik maksimum lokal lainnya atau nilai tertinggi kedua terjadi pada pukul 08.00 yang mana kemungkinan peminjam sepeda menggunakan sepeda untuk berangkat ke tempat bekerja. Dari grafik tampak terjadi kenaikan tren pada rentang pukul (04.00 hingga 08.00) dan rentang pukul pukul (14.00-17.00). Sementara itu, tren penurunan terjadi di malam hari.

# %%
hour_df.head()
# Out:
#    instant     dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1 2011-01-01       1   0     1   0        0        6           0
# 1        2 2011-01-01       1   0     1   1        0        6           0
# 2        3 2011-01-01       1   0     1   2        0        6           0
# 3        4 2011-01-01       1   0     1   3        0        6           0
# 4        5 2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp  atemp  hum  windspeed  casual  registered  cnt
# 0           1  0.24   0.29 0.81       0.00       3          13   16
# 1           1  0.22   0.27 0.80       0.00       8          32   40
# 2           1  0.22   0.27 0.80       0.00       5          27   32
# 3           1  0.24   0.29 0.75       0.00       3          10   13
# 4           1  0.24   0.29 0.75       0.00       0           1    1

# %%
plt.figure(figsize=(10, 6))
plt.plot(pivot_hr['hr'], pivot_hr['cnt'], marker='o', color='skyblue', linestyle='-')
plt.title('Average Bike Renting Number for Each Hour')
plt.xlabel('Hour')
plt.ylabel('Average Count')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Conclusion

# %% [markdown]
# - **Conclusion Pertanyaan 1**: Bagaimana hari mempengaruhi jumlah peminjaman sepeda?

# %% [markdown]
# Berdasarkan analisis data peminjaman sepeda terhadap hari, terlihat bahwa angka peminjaman sepeda tertinggi terjadi pada jumat dan diikuti hari kamis. Sementara itu, angka peminjaman terendah terjadi pada akhir pekan yakni hari sabtu (sekitar 4550 peminjaman) dan hari minggu (sekitar 4200 peminjaman). Sementara itu, pada hari senin terjadi 4338 peminjaman, hari selasa terjadi 4510 peminjaman sepeda, hari rabu terjadi 4548 peminjaman sepeda, hari kamis terjadi 4667 peminjaman sepeda, dan tertinggi pada hari jumat dengan 4690 peminjaman sepeda. Data tersebut terjadi karena mayoritas peminjam sepeda menggunakan untuk transportasi ke tempat kerja. Dari data tersebut, dapat disimpulkan bahwa hariberpengaruh terhadap minat konsumen dalam melakukan peminjaman sepeda. Hal ini dapat menjadi pertimbangan perusahaan penyedia peminjaman sepeda untuk memastikan ketersediaan sepeda dan menempatkan sepeda pada hari kerja di tempat-tempat yang berada di sekitar perkantoran.

# %% [markdown]
# - **Conclusion Pertanyaan 2**: Bagaimana musim mempengaruhi jumlah peminjaman sepeda pada periode tahun 2011 dan 2012?

# %% [markdown]
# Berdasarkan analisis data peminjaman sepeda terhadap musim dan cuaca serta line chart jumlah peminjaman sepeda berdasarkan musim tiap tahunnya, terlihat bahwa angka peminjaman sepeda tertinggi terjadi pada musim gugur dimana selama 2 tahun (2011-2012) menjcapai lebih dari 1 juta kali peminjaman. Sebaliknya, angka terendah peminjaman terjadi pada musim semi dimana selama 2 tahun (2011-2012) berada pada kisaran 500 ribu peminjaman. Pada dua musim lainnya, angka peminjaman pada musim panas adalah berkisar 900 ribu peminjaman dan musim dingin terjadi kisaran 800 ribu peminajaman. Berdasarkan data cuaca, tampak bahwa peminjaman tertinggi terjadi pada cuaca cerah dan peminjaman terendah terjadi pada cuaca hujan lebat. Dari data tersebut, dapat disimpulkan bahwa cuaca dan musim berpengaruh terhadap minat konsumen dalam melakukan peminjaman sepeda. Hal ini dapat menjadi pertimbangan perusahaan penyedia peminjaman sepeda untuk melakukan promosi pada musim dan cuaca dengan minat konsumen tertinggi untuk melakukan peminjaman sepeda.

# %% [markdown]
# - **Conclusion Pertanyaan 3**: Bagaimana waktu (jam) mempengaruhi jumlah peminjaman sepeda?

# %% [markdown]
# Berdasarkan analisis data peminjaman sepeda terhadap waktu/jam dalam satu hari dan  line chart jumlah peminjaman sepeda berdasarkan jam tiap harinya, terlihat bahwa angka peminjaman sepeda tertinggi terjadi pada pukul 17.00 dengan 461 peminjaman sepeda diikuti pada pukul 08.00 dengan 359 peminjaman sepeda. Sebaliknya, angka terendah peminjaman terjadi pada pukul 04.00 dengan 6 kasus peminjaman sepeda. Pada periode waktu subuh (01.00-04.00), peminjaman sepeda tergolong rendah sekitar 11-33 kasus demikian pada malam hari (23.00-00.00) sekitar 53-87 kasus. Data tersebut menunjukkan tingginya angka peminjaman sepeda pada jam berangkat kerja dan jam pulang dari tempat pekerjaan. Dari data tersebut, dapat disimpulkan bahwa waktuberpengaruh terhadap minat konsumen dalam melakukan peminjaman sepeda. Hal ini dapat menjadi pertimbangan perusahaan penyedia peminjaman sepeda untuk menjaring konsumen pada waktu pagi dan petang melalui promosi di tempat-tempat perumahaan dan perkantoran.

# %%
all_df = pd.merge(
    left=day_df,
    right=hour_df,
    how="left",
    left_on="instant",
    right_on="instant"
)
all_df.head()
# Out:
#    instant   dteday_x  season_x  yr_x  mnth_x  holiday_x  weekday_x  \
# 0        1 2011-01-01         1     0       1          0          6
# 1        2 2011-01-02         1     0       1          0          0
# 2        3 2011-01-03         1     0       1          0          1
# 3        4 2011-01-04         1     0       1          0          2
# 4        5 2011-01-05         1     0       1          0          3
#
#    workingday_x  weathersit_x  temp_x  ...  weekday_y  workingday_y  \
# 0             0             2    0.34  ...          6             0
# 1             0             2    0.36  ...          6             0
# 2             1             1    0.20  ...          6             0
# 3             1             1    0.20  ...          6             0
# 4             1             1    0.23  ...          6             0
#
#    weathersit_y  temp_y  atemp_y  hum_y windspeed_y  casual_y  registered_y  \
# ...

# %%
all_df.to_csv("all_data.csv", index=False)
